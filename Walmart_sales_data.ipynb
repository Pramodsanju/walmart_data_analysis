# %% [markdown]
# <a href="https://colab.research.google.com/github/Pramodsanju/walmart_data_analysis/blob/main/Walmart_sales_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv("/content/walmart-sales-dataset-of-45stores.csv")
data
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
import pandas as pd

# Assuming your date format is 'dd-mm-yyyy' (day-month-year)
data["Date"] = pd.to_datetime(data["Date"], format="%d-%m-%Y")

# %%
print(data.head(3))#to see few rowa of col
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106

# %%
print(data.info())#summarry
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   datetime64[ns]
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(2)
# memory usage: 402.3 KB
# None

# %%
print(data.describe())# statistical funtion
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.533501e+05      0.000000    47.460000     2.933000
# 50%      23.000000  9.607460e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.420159e+06      0.000000    74.940000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment
# count  6435.000000   6435.000000
# mean    171.578394      7.999151
# std      39.356712      1.875885
# min     126.064000      3.879000
# 25%     131.735000      6.891000
# 50%     182.616521      7.874000
# 75%     212.743293      8.622000
# max     227.232807     14.313000

# %%
print(data.columns)#columns
# Out:
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment'],
#       dtype='object')

# %%
print(data.isnull().sum())
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
# Display basic information about the dataset

data.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
data.tail()
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667

# %%
import matplotlib.pyplot as plt

# Split dataset into holiday and non-holiday weeks
holiday_sales = data[data["Holiday_Flag"] == 1]["Weekly_Sales"].mean()
non_holiday_sales = data[data["Holiday_Flag"] == 0]["Weekly_Sales"].mean()

# Create a comparison DataFrame
comparison_df = pd.DataFrame({
    "Category": ["Holiday", "Non-Holiday"],
    "Average Weekly Sales": [holiday_sales, non_holiday_sales]
})

# Plot comparison
plt.figure(figsize=(8, 5))
plt.bar(comparison_df["Category"], comparison_df["Average Weekly Sales"], color=["red", "blue"], edgecolor="black")
plt.title("Comparison of Weekly Sales: Holiday vs. Non-Holiday Weeks")
plt.ylabel("Average Weekly Sales ($)")
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show plot
plt.show()

# Display comparison DataFrame
comparison_df
# Out:
#       Category  Average Weekly Sales
# 0      Holiday          1.122888e+06
# 1  Non-Holiday          1.041256e+06

# %%
# Filter for the first 20 stores
top_20_stores = data["Store"].unique()[:20]

# Count the number of records per store (first 20 stores only)
store_counts_20 = data[data["Store"].isin(top_20_stores)]["Store"].value_counts().sort_index()

# Plot the number of entries per store (first 20 stores)
plt.figure(figsize=(8, 5))
store_counts_20.plot(kind="bar", color="skyblue")
plt.title("Number of Weekly Records per Store (First 20 Stores)")
plt.xlabel("Store ID")
plt.ylabel("Count of Records")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Compute total sales per store (first 20 stores only)
store_sales_20 = data[data["Store"].isin(top_20_stores)].groupby("Store")["Weekly_Sales"].sum().sort_values(ascending=False)

# Plot total sales per store (first 20 stores)
plt.figure(figsize=(10, 6))
store_sales_20.plot(kind="bar", color="red")
plt.title("Total Sales per Store (First 20 Stores)")
plt.xlabel("Store ID")
plt.ylabel("Total Sales ($)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Count the number of holiday vs. non-holiday weeks
holiday_counts = data["Holiday_Flag"].value_counts()

# Labels for the pie chart
labels = ["Non-Holiday Weeks", "Holiday Weeks"]

# Plot the pie chart
plt.figure(figsize=(8, 6))
plt.pie(
    holiday_counts,
    labels=labels,
    autopct="%1.1f%%",
    startangle=140,
    colors=["blue", "red"]
)

# Add a title
plt.title(f"Distribution of Holiday vs. Non-Holiday Weeks (Total Weeks: {data.shape[0]})")

# Show plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Extract the first 5 rows of required columns
subset = data.iloc[:5][['Weekly_Sales', 'Fuel_Price', 'Unemployment']]
labels = data.iloc[:5]['Store'].astype(str)  # Convert store numbers to string for labels

# Create the bar width
x = np.arange(len(labels))  # Label locations
width = 0.3  # Width of the bars

# Create the bar chart
fig, ax = plt.subplots(figsize=(8, 5))
rects1 = ax.bar(x - width, subset['Weekly_Sales'], width, label='Weekly Sales', color='blue')
rects2 = ax.bar(x, subset['Fuel_Price'], width, label='Fuel Price', color='red')
rects3 = ax.bar(x + width, subset['Unemployment'], width, label='Unemployment Rate', color='green')

# Add labels, title, and legend
ax.set_xlabel('Store ID')
ax.set_ylabel('Value')
ax.set_title('Comparison of Weekly Sales, Fuel Price, and Unemployment for First 5 Stores')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=45)
ax.legend()

# Show the plot
plt.show()

# %%
# Aggregate sales by store
store_sales = df.groupby("Store")["Weekly_Sales"].sum()

# Plot pie chart
plt.figure(figsize=(10, 6))
plt.pie(store_sales, labels=store_sales.index, autopct="%1.1f%%", startangle=140,
        colors=plt.cm.tab20.colors)  # Using colors from tab20 colormap
plt.title("Sales Distribution by Store ID")
plt.axis("equal")  # Ensures the pie chart is circular
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Compute correlation matrix
correlation_matrix = data.corr()

# Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()
